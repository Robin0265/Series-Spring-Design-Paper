# %% [markdown]
# # Deflection Curve for Thesis

# %% [markdown]
# ## Packages

# %%
import sys
sys.path.append("./")
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Table Overview

# %%
data = pd.read_csv("./2in1 Springs/Stiffness_Measure_250330_145102.csv", 
                   header=0)
data
# Out:
#        OSL:timestamp  OSL:_frequency  knee[DephyActpack]:output_position  \
# 0       1.743361e+09             500                            0.038702
# 1       1.743361e+09             500                            0.038687
# 2       1.743361e+09             500                            0.038695
# 3       1.743361e+09             500                            0.038695
# 4       1.743361e+09             500                            0.038702
# ...              ...             ...                                 ...
# 55996   1.743361e+09             500                            0.037621
# 55997   1.743361e+09             500                            0.037659
# 55998   1.743361e+09             500                            0.038549
# 55999   1.743361e+09             500                            0.038656
# 56000   1.743361e+09             500                            0.038725
#
#        knee[DephyActpack]:output_velocity  knee[DephyActpack]:accelx  \
# ...

# %%
time = data["OSL:timestamp"] - data["OSL:timestamp"][0]
output_position = data["knee[DephyActpack]:output_position"] - data["knee[DephyActpack]:output_position"][0]
torque = data["tau_futek"];

# %%
fig = plt.figure(figsize=(9, 6), dpi=200)
ax = fig.add_subplot(111)
plt.plot(-output_position, torque)

plt.rc('text', usetex=True)
plt.rc('font', family='serif')
plt.xlabel(r'time (s)', fontsize=14)
plt.ylabel(r'Displacement (m)',fontsize=14)

# Axis Ticks
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_visible(True)
ax.spines['left'].set_visible(True)
plt.savefig("../figs/RAW/Test.png")
